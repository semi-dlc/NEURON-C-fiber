# %%
from dataProcessing import getData, getFilename
import matplotlib.pyplot as plt

# %%
df = getData(prot=0)

# %%
t = df["Time"]

# %%
ax = df.axes[1]
axon_recordings = [ax for ax in df.axes[1] if "Axon" in ax]

# %%
df.plot(x='Time', y=axon_recordings, alpha=0.8)#, figsize=(12, 6))
plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig(f"{getFilename(prot=0)}_axons.pdf")
