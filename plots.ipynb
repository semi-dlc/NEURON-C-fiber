# %%
from dataProcessing import getData, getFilename
import matplotlib.pyplot as plt
from plot import plotLatency, plotRecoveryCycle

# %%
protocol = 42

# %%
potential = getData(prot=protocol)

# %%
t = potential["Time"]

# %%
ax = potential.axes[1]
axon_recordings = [ax for ax in potential.axes[1] if "Axon" in ax]

# %%
potential.plot(x='Time', y=axon_recordings, alpha=0.8)#, figsize=(12, 6))
plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig(f"{getFilename(prot=protocol)}_axons.pdf")

# %%
spikes = getData(prot=protocol, filetype="spikes")

# %%
stims = getData(prot=protocol, filetype="stim")

# %%
plotLatency(spikes, stims)

# %%
plotRecoveryCycle(spikes, stims) # nicht das was ich gedacht habe. extras scheint 250->25->10 zu sein
# Out:
# [np.float64(0.020279939548345283), np.float64(-0.0064264989632647485), np.float64(0.00046638408093713224), np.float64(0.006101139239035547), np.float64(-0.00217406265437603), np.float64(0.006495646055554971), np.float64(-0.0006864317110739648), np.float64(0.006581672816537321), np.float64(0.004483578784856945), np.float64(-0.006950643903110176), np.float64(0.0012630419223569334), np.float64(0.000538703752681613), np.float64(0.17280281329294667), np.float64(0.09991634567268193), np.float64(0.07470717956312001), np.float64(0.044721104262862355)]
# [2000, 1750, 1500, 1250, 1000, 750, 500, 250, 150, 100, 75, 50, 40, 30, 20, 10]
